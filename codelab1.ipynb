# %% [markdown]
# <a href="https://colab.research.google.com/github/imdummer1/assessment-1-code-lab/blob/main/codelab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================ Vending Machine Menu ================
def show_menu():
  print(" ")
  print("Menu:")
  # Chips
  print("Chips - 4 AED")
  cheetoes = 11
  print("11 - Cheetoes")
  lays = 12
  print("12 - Lays")
  doritos = 13
  print("13 - Doritos")

  print(" ")
  # Candy
  print("Candy - 2 AED")
  m_ms = 21
  print("21 - m&ms")
  oreos = 22
  print("22 - Oreos")

  print(" ")
  # Soda
  print("Soda - 5 AED")
  coca_cola = 31
  print("31 - Coca-Cola")
  pepsi = 32
  print("32 - Pepsi")
  dr_pepper = 33
  print("33 - Dr_Pepper")

show_menu()



# =================== Payment and Ordering ===================
# Prices
chips_price = 4
candy_price = 2
soda_price = 5

# Item groups
chips = [11,12,13]
candy = [21,22]
soda = [31,32,33]
# Out:
#
# Menu:
# Chips - 4 AED
# 11 - Cheetoes
# 12 - Lays
# 13 - Doritos
#
# Candy - 2 AED
# 21 - m&ms
# 22 - Oreos
#
# Soda - 5 AED
# 31 - Coca-Cola
# 32 - Pepsi
# 33 - Dr_Pepper
